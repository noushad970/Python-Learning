# %%
import numpy as nm
import pandas as p

# %%
dit={
    "Name":['Noushad','Nahid','Benoy'],
    "Age":[20,21,22],
    "Marks":[75,86,97],
    "City":['Dhaka','Barisal','Mymenshign']
}

# %%
df=p.DataFrame(dit)

# %%
df
# Out:
#       Name  Age  Marks        City
# 0  Noushad   20     75       Dhaka
# 1    Nahid   21     86     Barisal
# 2    Benoy   22     97  Mymenshign

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends2.csv",index=False)

# %%
df.head()
# Out:
#       Name  Age  Marks        City
# 0  Noushad   20     75       Dhaka
# 1    Nahid   21     86     Barisal
# 2    Benoy   22     97  Mymenshign

# %%
df.head(2)
# Out:
#       Name  Age  Marks     City
# 0  Noushad   20     75    Dhaka
# 1    Nahid   21     86  Barisal

# %%
df.tail(1)
# Out:
#     Name  Age  Marks        City
# 2  Benoy   22     97  Mymenshign

# %%
df.describe()
# Out:
#         Age  Marks
# count   3.0    3.0
# mean   21.0   86.0
# std     1.0   11.0
# min    20.0   75.0
# 25%    20.5   80.5
# 50%    21.0   86.0
# 75%    21.5   91.5
# max    22.0   97.0

# %%
st=p.read_csv('student.csv')

# %%
st
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
st.tail(4)
# Out:
#     id        name  class  mark  gender
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 33  34    Gain Toe  Seven    69    male
# 34  35  Rows Noump    Six    88  female

# %%
st["name"][0]
# Out:
# 'John Deo'

# %%
st["name"][0]="Noushad"
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17100\392138415.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   st["name"][0]="Noushad"
# ...

# %%
st.to_csv("student1.csv")

# %%
st.loc[["name"][0]]="Benoy"

# %%
st.head()
# Out:
#   id        name  class mark  gender
# 0  1     Noushad   Four   75  female
# 1  2    Max Ruin  Three   85    male
# 2  3      Arnold  Three   55    male
# 3  4  Krish Star   Four   60  female
# 4  5   John Mike   Four   60  female

# %%
st.loc[["name"][0]]
# Out:
# id        Benoy
# name      Benoy
# class     Benoy
# mark      Benoy
# gender    Benoy
# Name: name, dtype: object

# %%
st.head()
# Out:
#   id        name  class mark  gender
# 0  1     Noushad   Four   75  female
# 1  2    Max Ruin  Three   85    male
# 2  3      Arnold  Three   55    male
# 3  4  Krish Star   Four   60  female
# 4  5   John Mike   Four   60  female

# %%
st.loc[(st['mark']>80.0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 st.loc[(st['mark']>80.0)]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
# ...

# %%
st.loc()

# %%
st.loc

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 0 to name
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      36 non-null     object
#  1   name    36 non-null     object
#  2   class   36 non-null     object
#  3   mark    36 non-null     object
#  4   gender  36 non-null     object
# dtypes: object(5)
# memory usage: 2.7+ KB

# %%
st['mark'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:789, in nanmedian(values, axis, skipna, mask)
#     788 try:
# --> 789     values = values.astype("f8")
#     790 except ValueError as err:
#     791     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'Benoy'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 st['mark'].median()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:6570, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("median", ndim=1))
#    6563 def median(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# ...
